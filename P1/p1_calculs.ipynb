# %% [markdown]
# # Practica 1: uPython con ESP32 como dispositivo de adquisición de datos.
#
# Arnau Coronado i Guillem Castillo

# %% [markdown]
# led vermell: WW05A3SRP4-N 10,6 cd 630 nm 20 mA 2,0 V a 2,4 V en DC

# %%
# datos

iled=20e-3 # amps

# %%
iled=20e-3 # amps
vledmin=3.2
vledmax=4
rledmin=vledmin/iled
rledmax=vledmax/iled


iled = 20e-3  # amps
vledmin = 3.2
vledmax = 4

rledmin = vledmin / iled
rledmax = vledmax / iled

# Create a clean text output
text = f"Resistances for the LED: R_min = {rledmin:.2f} Ω, R_max = {rledmax:.2f} Ω"

print(text)
# Out:
# Resistances for the LED: R_min = 160.00 Ω, R_max = 200.00 Ω

# %%
iled=20e-3 # amps
v1=7
vledmin=3.2
vledmax=4
rshmin=(v1-vledmin)/iled
rshmax=(v1-vledmax)/iled
text = f"Resistances for the shunt resistence: R_min = {rshmin:.2f} Ω, R_max = {rshmax:.2f} Ω"
print(text)
# Out:
# Resistances for the shunt resistence: R_min = 190.00 Ω, R_max = 150.00 Ω

# %%
# Reductor de tensió

# %%
# v high

v1=7 #volts
vred=2.4 # volts
vyellow=4 # volts
vgreen=2.4 # volts
v2=v1-vred # volts
rred=(v1-vred)/iled # ohm
ryellow=(v1-vyellow)/iled # ohm
rgreen=(v1-vgreen)/iled # ohm
v3=v1*(r1/(r1+r2))


v2, v3, rred, ryellow, rgreenn
# Out:
# (4.6, 3.5, 229.99999999999997, 150.0, 229.99999999999997)

# %%
2*255/3.3
# Out:
# 154.54545454545456
